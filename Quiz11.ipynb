# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Calculus_2/blob/main/Quiz11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def a(n):
  return (-1)**n/(3*2**(n+1))

# %%
sum([a(n) for n in range(100000)])
# Out:
# 0.1111111111111111

# %%
import sympy

n = sympy.Symbol('n')

a = 1/(n+3)

a.diff(n)
# Out:
# -1/(n + 3)**2

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,1000,1)
y = x*np.sin(1/x)

plt.scatter(x,y)
plt.show()
