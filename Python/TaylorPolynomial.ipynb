# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Calculus_2/blob/main/Python/TaylorPolynomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def b(n,x): #each term in taylor expansion of e^x
  return 1/math.factorial(n)*x**n

def a(n,x): #the nth order polynomial for e^v
  return sum([b(i,x) for i in range(n+1)])

# %%
a(100,2)
# Out:
# 7.38905609893065

# %%
math.e**2
# Out:
# 7.3890560989306495

# %%
import matplotlib.pyplot as plt
import numpy as np

x_values = np.linspace(-10, 5, 400) # Range for x

# Calculate y values for e**x
y_exp = np.exp(x_values)

# Calculate y values for a(n,x) for n=1, 2, 25
y_a1 = [a(1, x) for x in x_values]
y_a2 = [a(2, x) for x in x_values]
y_a5 = [a(25, x) for x in x_values]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_exp, label=r'$e^x$', linestyle='--')
plt.plot(x_values, y_a1, label=r'$T_1(x)$')
plt.plot(x_values, y_a2, label=r'$T_2(x)$')
plt.plot(x_values, y_a5, label=r'$T_{25}(x)$')

plt.title(r'Comparison of $e^x$ and $T_n(x)$ functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.ylim(-1, 20)
plt.show()
