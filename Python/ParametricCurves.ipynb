# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Calculus_2/blob/main/Python/ParametricCurves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parametric Curves

# %%
from sympy import *
x,t,n,r = symbols(('x','t','n','r'))

# %%
plot_parametric(t**4-t**3+7,t,(t,-5,5))

# %%
entry = (-1)**n*x**(2*n+5)/(factorial(n)*factorial(n+5)*2**(2*n+5))
entry
# Out:
# (-1)**n*2**(-2*n - 5)*x**(2*n + 5)/(factorial(n)*factorial(n + 5))

# %%
partsum1 = entry.subs(n,0)+entry.subs(n,1)
partsum1
# Out:
# -x**7/92160 + x**5/3840

# %%
partsum10 = 0

for i in range(50):
  partsum10 += entry.subs(n,i)

# %%
plot(besselj(5,x),(x,0,10))

# %%
plot(partsum10,(x,0,10))

# %% [markdown]
# ##2

# %%
plot_parametric(5*sin(16*t),17*cos(17*t),(t,0,2*pi))

# %%
plot_parametric(26*t-26*cos(t),26-26*sin(t),(t,0,10))

# %%
plot_parametric((t**2,t**3-3*t),(t+3,sqrt(3)*(t+3)-3*sqrt(3)),(t+3,-sqrt(3)*(t+3)+3*sqrt(3)),(0,t),(t,2),(t,-2),(t,-2,2))

# %%
plot_parametric(t**3/4-t+1,t**2/4-1,(t,-2,2))

# %%
r = 1+sin(t)

#matplotlib inline
plot_parametric( r*cos(t), r*sin(t), (t, 0, 2*pi))

# %% [markdown]
# This is called the cartoid (heart!)

# %%
t = 2*pi*r

#matplotlib inline
plot_parametric( r*cos(t), r*sin(t), (r, 0, 20))
