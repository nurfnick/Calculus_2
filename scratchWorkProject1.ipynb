# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Calculus_2/blob/main/scratchWorkProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy
import math

x = sympy.Symbol("x")

# %%
f = 1/sympy.sqrt(10*x+1)

f
# Out:
# 1/sqrt(10*x + 1)

# %%
sympy.plot(f, (x, 0, 1))

# %%
y1 = sympy.E**x
y2 = sympy.sqrt(10*x)+1

# %%
sympy.plot(y1, y2, (x, 0, 2))

# %%
sympy.nsolve(y1-y2,x,1.6)
# Out:
# 1.61256914387177

# %%
lower = sympy.nsolve(y1-y2,x,0)
# Out:
# 0

# %%
left = sympy.integrate(sympy.ln(x)**10,x)

left
# Out:
# x*log(x)**10 - 10*x*log(x)**9 + 90*x*log(x)**8 - 720*x*log(x)**7 + 5040*x*log(x)**6 - 30240*x*log(x)**5 + 151200*x*log(x)**4 - 604800*x*log(x)**3 + 1814400*x*log(x)**2 - 3628800*x*log(x) + 3628800*x

# %%
right = x*sympy.ln(x)**10-10*sympy.integrate(sympy.ln(x)**9,x)

right
# Out:
# x*log(x)**10 - 10*x*log(x)**9 + 90*x*log(x)**8 - 720*x*log(x)**7 + 5040*x*log(x)**6 - 30240*x*log(x)**5 + 151200*x*log(x)**4 - 604800*x*log(x)**3 + 1814400*x*log(x)**2 - 3628800*x*log(x) + 3628800*x

# %%
sympy.diff(right,x)
# Out:
# log(x)**10

# %%
from sympy import *

diff(right,x)
# Out:
# log(x)**10
